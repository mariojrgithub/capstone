# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('./retrosplits/daybyday/teams-2018.csv')
# Out:
#           game.key game.source   game.date  game.number site.key season.phase  \
# 0     NLS201807170         evt  2018-07-17            0    WAS11            A
# 1     OAK201803290         evt  2018-03-29            0    OAK01            R
# 2     OAK201803300         evt  2018-03-30            0    OAK01            R
# 3     OAK201803310         evt  2018-03-31            0    OAK01            R
# 4     OAK201804010         evt  2018-04-01            0    OAK01            R
# 5     ANA201804020         evt  2018-04-02            0    ANA01            R
# 6     ANA201804030         evt  2018-04-03            0    ANA01            R
# 7     ANA201804040         evt  2018-04-04            0    ANA01            R
# 8     ANA201804060         evt  2018-04-06            0    ANA01            R
# 9     ANA201804070         evt  2018-04-07            0    ANA01            R
# 10    ANA201804080         evt  2018-04-08            0    ANA01            R
# ...

# %%
pd.read_csv('./retrosplits/splits/headtohead-2018.csv')
# Out:
#        YEAR PHASE RESP_BAT_ID RESP_PIT_ID  B_PA  B_AB  B_H  B_TB  B_2B  B_3B  \
# 0      2018     D    acunr001    baezp001     2     1    0     0     0     0
# 1      2018     D    acunr001    buehw001     3     3    1     4     0     0
# 2      2018     D    acunr001    fergc001     1     1    0     0     0     0
# 3      2018     D    acunr001    hillr001     3     3    0     0     0     0
# 4      2018     D    acunr001    jansk001     2     2    1     1     0     0
# 5      2018     D    acunr001    kersc001     3     3    1     2     1     0
# 6      2018     D    acunr001    ryu-h001     3     3    0     0     0     0
# 7      2018     D    adaml001    fergc001     1     1    0     0     0     0
# 8      2018     D    adaml001    kersc001     1     0    0     0     0     0
# 9      2018     D    aguij001    andet002     3     3    0     0     0     0
# 10     2018     D    aguij001    marqg001     2     2    1     4     0     0
# ...
